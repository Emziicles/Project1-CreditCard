# %% [markdown]
# # Credit Card Customers
# ### Group: 3 (No pun intended)
# ## Background:
# A manager at the bank is disturbed with more and more customers leaving their credit card services. They would really appreciate if one could predict for them who is gonna get churned so they can proactively go to the customer to provide them better services and turn customers' decisions in the opposite direction.
# ## Objectives / Development Reuirements:
# 1. Using pandas to clean and format your datasset(s).
# 2. Creating a Jupyter Notebook describing the data exploration and cleanup process.
# 3. Creating a Jupyter Notebook illustrating the final data analysis using Matplotlib to create a total of 6-8 visualisaations of your data (ideally at least 2 per "question" aked of your data)
# 4. Saving PNG images of your visualisations to disribute to the class and instructional team, and for inclusion in your presentation
# 5. (Optional) using at least one API if you can find an API with data applicable to your primary research questions.
# 6. Create a write-up summarising your major findings. This should include a heading for each "Question you asked of your data and a short description of your findings and any other plots.
# ## Scope of Research
# ...still to be determined...

# %%
import pandas as pd
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# Read the '.csv' file.
CCCP_data = pd.read_csv('../Resources/BankChurners.csv')
CCCP_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# # Data Preparation, Cleaning and Formatting

# %%
# drop any columns of the data that we will not need or investigate. - Drop last columns.
# displays the number of months and number of customers are inactive
CCCP_data["Months_Inactive_12_mon"].value_counts()
CCCP_data.drop(columns=["Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1"], inplace=True)
CCCP_data.drop(columns=["Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"], inplace=True)

# %%
CCCP_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
CCCP_data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# check Dtype.

# %%
# Statystical Analysis
# check the mean, max, count, standard deviation etc.

# %%
# check for any null values in the dataset

# %% [markdown]
# ## Key Questions:
# ### 1. Comparing gender and age to credit card users that have stayed and left?

# %%
# columns needed for this are Gender, Customer_Age, Attrition_Flag
Q1_columns = ["Gender", "Customer_Age", "Attrition_Flag"]
Q1_df = CCCP_data[Q1_columns]
Q1_index=Q1_df.set_index(["Gender","Customer_Age","Attrition_Flag",])
Q1_index=Q1_index.groupby(level = ["Gender", "Customer_Age", "Attrition_Flag"])
Q1_index.count()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
# comparison of Gender, Customer_Age and Attrition_Flag

# %% [markdown]
# ### 2. Does gender/age/marital status and dependents affect how long they have stayed with the bank? What’s the family situation like?

# %%
# columns needed for this are Customer_Age, Gender, Marital_Status, Dependant_count, Months_on_book
Q2_columns = ["Customer_Age", "Gender", "Marital_Status", "Dependent_count","Months_on_book"]
Q2_df = CCCP_data[Q2_columns]
Q2_df
# Out:
#        Customer_Age Gender Marital_Status  Dependent_count  Months_on_book
# 0                45      M        Married                3              39
# 1                49      F         Single                5              44
# 2                51      M        Married                3              36
# 3                40      F        Unknown                4              34
# 4                40      M        Married                3              21
# ...             ...    ...            ...              ...             ...
# 10122            50      M         Single                2              40
# 10123            41      M       Divorced                2              25
# 10124            44      F        Married                1              36
# 10125            30      M        Unknown                2              36
# 10126            43      F        Married                2              25
#
# [10127 rows x 5 columns]

# %% [markdown]
# ### 3. How long have they been inactive? Compare this between the existing and left customers and is there someway we can predict which existing customers will leave?

# %%
# columns needed for this are Months_Inactive_1_mon, Attrition_Flag, Months_on_book
Q3_columns = ["Months_Inactive_12_mon", "Attrition_Flag", "Months_on_book"]
Q3_df = CCCP_data[Q3_columns]
Q3_df
# Out:
#        Months_Inactive_12_mon     Attrition_Flag  Months_on_book
# 0                           1  Existing Customer              39
# 1                           1  Existing Customer              44
# 2                           1  Existing Customer              36
# 3                           4  Existing Customer              34
# 4                           1  Existing Customer              21
# ...                       ...                ...             ...
# 10122                       2  Existing Customer              40
# 10123                       2  Attrited Customer              25
# 10124                       3  Attrited Customer              36
# 10125                       3  Attrited Customer              36
# 10126                       2  Attrited Customer              25
#
# [10127 rows x 3 columns]

# %% [markdown]
# ### 4. The relationship of credit card users in relation to education and income levels – do higher education and income correlate? Are they more likely to stay with the bank? Does the number of dependents tie into this? People with a lower income and more dependents more likely to leave?

# %%
# columns needed for this are Education_level, Income_category, Attrition_Flag, Dependant_count
Q4_columns = ["Education_Level", "Income_Category", "Attrition_Flag","Dependent_count"]
Q4_df = CCCP_data[Q4_columns]
Q4_df
# Out:
#       Education_Level Income_Category     Attrition_Flag  Dependent_count
# 0         High School     $60K - $80K  Existing Customer                3
# 1            Graduate  Less than $40K  Existing Customer                5
# 2            Graduate    $80K - $120K  Existing Customer                3
# 3         High School  Less than $40K  Existing Customer                4
# 4          Uneducated     $60K - $80K  Existing Customer                3
# ...               ...             ...                ...              ...
# 10122        Graduate     $40K - $60K  Existing Customer                2
# 10123         Unknown     $40K - $60K  Attrited Customer                2
# 10124     High School  Less than $40K  Attrited Customer                1
# 10125        Graduate     $40K - $60K  Attrited Customer                2
# 10126        Graduate  Less than $40K  Attrited Customer                2
#
# [10127 rows x 4 columns]

# %% [markdown]
# ### 5. The relationship between card category and income? Are those with higher income on a better card? Are they more likely to stay or leave?

# %%
# columns needed for this are Card_Category, Income_Category, Attrition_Flag
Q5_columns = ["Card_Category", "Income_Category", "Attrition_Flag"]
Q5_df = CCCP_data[Q5_columns]
Q5_df
# Out:
#       Card_Category Income_Category     Attrition_Flag
# 0              Blue     $60K - $80K  Existing Customer
# 1              Blue  Less than $40K  Existing Customer
# 2              Blue    $80K - $120K  Existing Customer
# 3              Blue  Less than $40K  Existing Customer
# 4              Blue     $60K - $80K  Existing Customer
# ...             ...             ...                ...
# 10122          Blue     $40K - $60K  Existing Customer
# 10123          Blue     $40K - $60K  Attrited Customer
# 10124          Blue  Less than $40K  Attrited Customer
# 10125          Blue     $40K - $60K  Attrited Customer
# 10126        Silver  Less than $40K  Attrited Customer
#
# [10127 rows x 3 columns]

# %% [markdown]
# ### 6. Do total transaction levels tie in with income levels? And is there any correlation between transaction amounts and how long customers have been inactive?

# %%
# columns needed for this are Total_Trans_Amt, Total_Trans_Ct, Months_Inactive_12_mon, Income_Category
Q6_columns = ["Total_Trans_Amt", "Total_Trans_Ct", "Months_Inactive_12_mon","Income_Category"]
Q6_df = CCCP_data[Q6_columns]
Q6_df["Income_Category"].value_counts()
Q6_df.head()
# Out:
#    Total_Trans_Amt  Total_Trans_Ct  Months_Inactive_12_mon Income_Category
# 0             1144              42                       1     $60K - $80K
# 1             1291              33                       1  Less than $40K
# 2             1887              20                       1    $80K - $120K
# 3             1171              20                       4  Less than $40K
# 4              816              28                       1     $60K - $80K

# %%
Q6_df["Income_Category"].count()
print(Q6_df["Income_Category"].max())
print(Q6_df["Income_Category"].min())
# Out:
# Unknown
# $120K +

# %%
#dropping the "unknown" Income category as it is not sure where it falls and it is only 10% of the total data. 
Q6_df = Q6_df[Q6_df['Income_Category'] != "Unknown"]
Q6_df_income_cat_count=Q6_df["Income_Category"].value_counts()
#Q6_df["Income_Category"].count()
Q6_df_income_cat_count
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# $120K +            727
# Name: Income_Category, dtype: int64

# %%
Q6_df
# Out:
#        Total_Trans_Amt  Total_Trans_Ct  Months_Inactive_12_mon Income_Category
# 0                 1144              42                       1     $60K - $80K
# 1                 1291              33                       1  Less than $40K
# 2                 1887              20                       1    $80K - $120K
# 3                 1171              20                       4  Less than $40K
# 4                  816              28                       1     $60K - $80K
# ...                ...             ...                     ...             ...
# 10122            15476             117                       2     $40K - $60K
# 10123             8764              69                       2     $40K - $60K
# 10124            10291              60                       3  Less than $40K
# 10125             8395              62                       3     $40K - $60K
# 10126            10294              61                       2  Less than $40K
#
# [9015 rows x 4 columns]

# %%
Q6_df_groupby_Income_cat=Q6_df.groupby(["Income_Category"])
#Q6_df_groupby_Income_cat.head()
Q6_df_Income_n_TotalTrans=Q6_df_groupby_Income_cat["Total_Trans_Ct"].count()
Q6_df_Income_n_TotalTrans
# Out:
# Income_Category
# $120K +            727
# $40K - $60K       1790
# $60K - $80K       1402
# $80K - $120K      1535
# Less than $40K    3561
# Name: Total_Trans_Ct, dtype: int64

# %%
IncomeCat_vs_TotalTrans_df = pd.DataFrame(Q6_df["Income_Category"].value_counts()).reset_index()
IncomeCat_vs_TotalTrans_df.rename(columns={"index":"Income Category", "Income_Category":"Count"},inplace=True)
IncomeCat_vs_TotalTrans_df
# Out:
#   Income Category  Count
# 0  Less than $40K   3561
# 1     $40K - $60K   1790
# 2    $80K - $120K   1535
# 3     $60K - $80K   1402
# 4         $120K +    727

# %%
Q6_df_Income_n_TotalTrans.values
# Out:
# array([ 727, 1790, 1402, 1535, 3561], dtype=int64)

# %%
list(Q6_df_Income_n_TotalTrans.values)
# Out:
# [727, 1790, 1402, 1535, 3561]

# %%
IncomeCat_vs_TotalTrans_df=pd.DataFrame({"Income Category":list(Q6_df_Income_n_TotalTrans.index), 
                                         "Customer Count":list(Q6_df_Income_n_TotalTrans.values)})
IncomeCat_vs_TotalTrans_df
# Out:
#   Income Category  Customer Count
# 0         $120K +             727
# 1     $40K - $60K            1790
# 2     $60K - $80K            1402
# 3    $80K - $120K            1535
# 4  Less than $40K            3561

# %%
#IncomeCat_vs_TotalTrans_df.plot(kind='bar',x='Income Category', y='Customer Count')

IncomeCat_vs_TotalTrans_df.plot(kind='bar', x="Income Category", y="Customer Count",color='blue')
#fig = plt.figure()
#fig.suptitle('IncomeCat_vs_TotalTrans')
plt.suptitle('"Income Category" vs "Total Transactions"', fontsize=15)
plt.xlabel("Income Category",fontsize=10)
plt.ylabel("Customer Count",fontsize=10)
plt.xticks(fontsize= 5, rotation=45)
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Q6_df
# Out:
#        Total_Trans_Amt  Total_Trans_Ct  Months_Inactive_12_mon Income_Category
# 0                 1144              42                       1     $60K - $80K
# 1                 1291              33                       1  Less than $40K
# 2                 1887              20                       1    $80K - $120K
# 3                 1171              20                       4  Less than $40K
# 4                  816              28                       1     $60K - $80K
# ...                ...             ...                     ...             ...
# 10122            15476             117                       2     $40K - $60K
# 10123             8764              69                       2     $40K - $60K
# 10124            10291              60                       3  Less than $40K
# 10125             8395              62                       3     $40K - $60K
# 10126            10294              61                       2  Less than $40K
#
# [9015 rows x 4 columns]

# %%
Q6_df_groupby_monthInactive=Q6_df.groupby(["Months_Inactive_12_mon"])
Q6_df_groupby_monthInactive_TotalTransAmt=Q6_df_groupby_monthInactive["Total_Trans_Ct"].count()
#Q6_df_groupby_monthInactive_TotalTransAmt.plot()
#Q6_df_groupby_monthInactive_TotalTransAmt_sum=Q6_df_groupby_monthInactive["Total_Trans_Amt"].sum()
#Q6_df_groupby_monthInactive_TotalTransAmt_sum

# %%
MonthsInactive_vs_Total_trans=pd.DataFrame(Q6_df_groupby_monthInactive["Total_Trans_Ct"].count())

MonthsInactive_vs_Total_trans.rename(columns={"MonthsInactive_12_mon":"Months Inactive", "Total_Trans_Ct":"Num Of Trans"},inplace=True)
MonthsInactive_vs_Total_trans.reset_index(inplace=True)
#MonthsInactive_vs_Total_trans.to_frame().reset_index().dtypes()
MonthsInactive_vs_Total_trans
# Out:
#    Months_Inactive_12_mon  Num Of Trans
# 0                       0            23
# 1                       1          1982
# 2                       2          2959
# 3                       3          3410
# 4                       4           374
# 5                       5           159
# 6                       6           108

# %%
MonthsInactive_vs_Total_trans
# Out:
#    Months_Inactive_12_mon  Num Of Trans
# 0                       0            23
# 1                       1          1982
# 2                       2          2959
# 3                       3          3410
# 4                       4           374
# 5                       5           159
# 6                       6           108

# %%
list(MonthsInactive_vs_Total_trans.index)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
MonthsInactive_vs_Total_trans.values
# Out:
# array([[   0,   23],
#        [   1, 1982],
#        [   2, 2959],
#        [   3, 3410],
#        [   4,  374],
#        [   5,  159],
#        [   6,  108]], dtype=int64)

# %%
MonthsInactive_vs_Total_trans.plot(kind='bar', x="Months_Inactive_12_mon", y="Num Of Trans")
plt.suptitle('"Months Inactive" vs "Total Transactions"', fontsize=15)
plt.xlabel("Months Inactive")
plt.show
plt.ylabel("Num Of Trans")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Credit Card Customers
# ### Group: 3 (No pun intended)
# ## Background:
# A manager at the bank is disturbed with more and more customers leaving their credit card services. They would really appreciate if one could predict for them who is gonna get churned so they can proactively go to the customer to provide them better services and turn customers' decisions in the opposite direction.
# ## Objectives / Development Reuirements:
# 1. Using pandas to clean and format your datasset(s).
# 2. Creating a Jupyter Notebook describing the data exploration and cleanup process.
# 3. Creating a Jupyter Notebook illustrating the final data analysis using Matplotlib to create a total of 6-8 visualisaations of your data (ideally at least 2 per "question" aked of your data)
# 4. Saving PNG images of your visualisations to disribute to the class and instructional team, and for inclusion in your presentation
# 5. (Optional) using at least one API if you can find an API with data applicable to your primary research questions.
# 6. Create a write-up summarising your major findings. This should include a heading for each "Question you asked of your data and a short description of your findings and any other plots.
# ## Scope of Research
# ...still to be determined...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the '.csv' file.
CCCP_data = pd.read_csv(r'C:\Users\joe_o\Desktop\myPythonStuff\BankChurners.csv')
CCCP_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# # Data Preparation, Cleaning and Formatting

# %%
# drop any columns of the data that we will not need or investigate. - Drop last columns.
# displays the number of months and number of customers are inactive
CCCP_data["Months_Inactive_12_mon"].value_counts()
CCCP_data.drop(columns=["Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1", "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"], inplace=True)

# %%
CCCP_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# check Dtype.
CCCP_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
# Statystical Analysis
# check the mean, max, count, standard deviation etc.
CCCP_data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
# check for any null values in the dataset
# '.isnull()' This will return boolean value for every column in the data frame, i.e. if the vale is null it returns True, and False values are other than null.
CCCP_data.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0          False           False         False   False            False
# 1          False           False         False   False            False
# 2          False           False         False   False            False
# 3          False           False         False   False            False
# 4          False           False         False   False            False
# ...          ...             ...           ...     ...              ...
# 10122      False           False         False   False            False
# 10123      False           False         False   False            False
# 10124      False           False         False   False            False
# 10125      False           False         False   False            False
# 10126      False           False         False   False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# ...

# %%
#  total number of null values in each features in the data frame.
CCCP_data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# ## Analysis and Visualisation

# %% [markdown]
# ## Key Questions:
# ### 1. Comparing gender and age to credit card users that have stayed and left?

# %%
# columns needed for this are Gender, Customer_Age, Attrition_Flag
Q1_columns = ["Gender", "Customer_Age", "Attrition_Flag"]
Q1_df = CCCP_data[Q1_columns]
Q1_df
# Out:
#       Gender  Customer_Age     Attrition_Flag
# 0          M            45  Existing Customer
# 1          F            49  Existing Customer
# 2          M            51  Existing Customer
# 3          F            40  Existing Customer
# 4          M            40  Existing Customer
# ...      ...           ...                ...
# 10122      M            50  Existing Customer
# 10123      M            41  Attrited Customer
# 10124      F            44  Attrited Customer
# 10125      M            30  Attrited Customer
# 10126      F            43  Attrited Customer
#
# [10127 rows x 3 columns]

# %%
# determining the percentage of existing customer vs churned customers
# using the '.count()' function we can determine the number of attritted customers
num_att_customer = CCCP_data[CCCP_data.Attrition_Flag=="Attrited Customer"].Attrition_Flag.count()
# to get the total number of customers the function '.nunique()' was used looking at the CLIENTNUM
tot_num_customer = CCCP_data.CLIENTNUM.nunique()
# number of existing customers can be determined by subtraction
num_exist_customer = tot_num_customer - num_att_customer

# determine the percentages of each customer "base"
att_customer_percent = (num_att_customer / tot_num_customer)*100
exist_customer_percent = (num_exist_customer / tot_num_customer)*100
# print text to show the distribution existing and churned customers in the dataset
print('The dataset consists of {:.2f}% which are Existing Customers and {:.2f}% which are customers who have churned / left the bank.'.format(exist_customer_percent, att_customer_percent))
# visualise this using a pie chart
Q1_df["Attrition_Flag"].value_counts().plot(kind="pie", y="Attrition_Flag", autopct="%1.1f%%", colors=["slateblue", "orchid"])
# Out:
# The dataset consists of 83.93% which are Existing Customers and 16.07% which are customers who have churned / left the bank.
# <AxesSubplot:ylabel='Attrition_Flag'>

# %%
# determine the distribution of gender in the number of exiting and churned customers
# for the churned customers
att_customer_M = CCCP_data[(CCCP_data.Attrition_Flag=="Attrited Customer") & (CCCP_data.Gender=="M")].Attrition_Flag.count()
churned_M = (att_customer_M / num_att_customer)*100
att_customer_F = CCCP_data[(CCCP_data.Attrition_Flag=="Attrited Customer") & (CCCP_data.Gender=="F")].Attrition_Flag.count()
churned_F = (att_customer_F / num_att_customer)*100
# for the existing customers
exist_customer_M = CCCP_data[(CCCP_data.Attrition_Flag=="Existing Customer") & (CCCP_data.Gender=="M")].Attrition_Flag.count()
exist_M = (exist_customer_M / num_exist_customer)*100
exist_customer_F = CCCP_data[(CCCP_data.Attrition_Flag=="Existing Customer") & (CCCP_data.Gender=="F")].Attrition_Flag.count()
exist_F = (exist_customer_F / num_exist_customer)*100
# print text to show the distritbution of gender in the existing and churned customers in the dataset
print('Within the Existing Customers {:.2f}% are Male and {:.2f}% Female'.format(exist_M, exist_F))
print('and within the Churned Customers {:.2f}% are Male and {:.2f}% Female'.format(churned_M, churned_F))

# to visulaise this dataset
customer_status = list(CCCP_data.Attrition_Flag.unique())
Male = [churned_M, exist_M]
Female = [churned_F, exist_F]

width = 0.40
plt.subplot(1, 2, 2)
index = np.arange(len(customer_status))
index_2 = [i + width for i in index]

plt.bar(index, Male, width=width, color = 'lightblue', label = "Male")
plt.bar(index_2, Female, width=width, color = 'pink', label = "Female")
plt.xticks(index, customer_status, color = 'black', rotation = 30)
plt.legend()
# Out:
# Within the Existing Customers 47.91% are Male and 52.09% Female
# and within the Churned Customers 42.84% are Male and 57.16% Female

# %% [markdown]
# ### 2. Does gender/age/marital status and dependents affect how long they have stayed with the bank? What’s the family situation like?

# %%
# columns needed for this are Customer_Age, Gender, Marital_Status, Dependant_count, Months_on_book
Q2_columns = ["Gender", "Customer_Age", "Attrition_Flag"]
Q1_df = CCCP_data[Q1_columns]
Q1_df
# Out:
#       Gender  Customer_Age     Attrition_Flag
# 0          M            45  Existing Customer
# 1          F            49  Existing Customer
# 2          M            51  Existing Customer
# 3          F            40  Existing Customer
# 4          M            40  Existing Customer
# ...      ...           ...                ...
# 10122      M            50  Existing Customer
# 10123      M            41  Attrited Customer
# 10124      F            44  Attrited Customer
# 10125      M            30  Attrited Customer
# 10126      F            43  Attrited Customer
#
# [10127 rows x 3 columns]

# %% [markdown]
# ### 3. How long have they been inactive? Compare this between the existing and left customers and is there someway we can predict which existing customers will leave?

# %%
# columns needed for this are Months_Inactive_1_mon, Attrition_Flag, Months_on_book
Q1_columns = ["Gender", "Customer_Age", "Attrition_Flag"]
Q1_df = CCCP_data[Q1_columns]
Q1_df
# Out:
#       Gender  Customer_Age     Attrition_Flag
# 0          M            45  Existing Customer
# 1          F            49  Existing Customer
# 2          M            51  Existing Customer
# 3          F            40  Existing Customer
# 4          M            40  Existing Customer
# ...      ...           ...                ...
# 10122      M            50  Existing Customer
# 10123      M            41  Attrited Customer
# 10124      F            44  Attrited Customer
# 10125      M            30  Attrited Customer
# 10126      F            43  Attrited Customer
#
# [10127 rows x 3 columns]

# %% [markdown]
# ### 4. The relationship of credit card users in relation to education and income levels – do higher education and income correlate? Are they more likely to stay with the bank? Does the number of dependents tie into this? People with a lower income and more dependents more likely to leave?

# %%
# columns needed for this are Education_level, Incomce_category, Attrition_Flag, Dependant_count
Q4_columns = ["Education_Level", "Income_Category", "Attrition_Flag", "Dependent_count"]
Q4_df = CCCP_data[Q4_columns]
Q4_df_drop = Q4_df.drop(Q4_df.index[Q4_df['Education_Level']=='Unknown'], inplace=True)
Q4_df_drop
# Out:
# C:\Users\joe_o\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# display graph showing income level against the attrition flag
income_cat_att = CCCP_data[CCCP_data.Attrition_Flag=="Attrited Customer"].Income_Category.value_counts()
income_cat_att
income_att_drop = income_cat_att.drop(index=["Unknown"])
income_att_drop
# Out:
# Less than $40K    612
# $40K - $60K       271
# $80K - $120K      242
# $60K - $80K       189
# $120K +           126
# Name: Income_Category, dtype: int64

# %%
income_cat_exist = CCCP_data[CCCP_data.Attrition_Flag=="Existing Customer"].Income_Category.value_counts()
income_cat_exist
income_exist_drop = income_cat_exist.drop(index=["Unknown"])
income_exist_drop
# Out:
# Less than $40K    2949
# $40K - $60K       1519
# $80K - $120K      1293
# $60K - $80K       1213
# $120K +            601
# Name: Income_Category, dtype: int64

# %%
plt.figure(figsize=(12,9))
plt.plot(income_att_drop, color='purple', label='Churned Customers')
plt.plot(income_exist_drop, color='pink', label='Existing Customers')
plt.xlabel("Income Catgory")
plt.ylabel("Number of Customers")
plt.legend()

# %%
edu_att = CCCP_data[CCCP_data.Attrition_Flag=="Attrited Customer"].Education_Level.value_counts()
edu_att
# Out:
# Graduate         487
# High School      306
# Unknown          256
# Uneducated       237
# College          154
# Doctorate         95
# Post-Graduate     92
# Name: Education_Level, dtype: int64

# %%
edu_exist = CCCP_data[CCCP_data.Attrition_Flag=="Existing Customer"].Education_Level.value_counts()
edu_exist
# Out:
# Graduate         2641
# High School      1707
# Unknown          1263
# Uneducated       1250
# College           859
# Post-Graduate     424
# Doctorate         356
# Name: Education_Level, dtype: int64

# %%
barplot = sns.countplot(y="Education_Level", hue="Attrition_Flag", data=Q4_df)

# %%
bins = [0, 2, 4, 5, 6]
labels = ["0-1", "2-3", "3-4", "5+"]
new_Q4_df = Q4_df["Dependants Grouped"] = pd.cut(Q4_df["Dependent_count"], bins, labels=labels)
# Out:
# <ipython-input-86-04a5f1442c5d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_Q4_df = Q4_df["Dependants Grouped"] = pd.cut(Q4_df["Dependent_count"], bins, labels=labels)

# %%
merge_Q4_df = pd.merge(Q4_df, new_Q4_df, how="left", on="Dependent_count")
merge_Q4_df
# Out:
#      Education_Level Income_Category     Attrition_Flag Dependent_count  \
# 0        High School     $60K - $80K  Existing Customer               3
# 1           Graduate  Less than $40K  Existing Customer               5
# 2           Graduate    $80K - $120K  Existing Customer               3
# 3        High School  Less than $40K  Existing Customer               4
# 4         Uneducated     $60K - $80K  Existing Customer               3
# ...              ...             ...                ...             ...
# 8603        Graduate  Less than $40K  Existing Customer               1
# 8604        Graduate     $40K - $60K  Existing Customer               2
# 8605     High School  Less than $40K  Attrited Customer               1
# 8606        Graduate     $40K - $60K  Attrited Customer               2
# 8607        Graduate  Less than $40K  Attrited Customer               2
#
#      Dependants Grouped
# 0                   2-3
# 1                   3-4
# 2                   2-3
# ...

# %%
dep_att_customer = merge_Q4_df.loc[Q4_df_drop["Attrition_Flag"]=="Attrited Customer"]
dep_exist_customer = merge_Q4_df.loc[Q4_df_drop["Attrition_Flag"]=="Existing Customer"]

plot_att = dep_att_customer["Dependants Grouped"].value_counts().sort_index(ascending=True)
plot_exist = dep_exist_customer["Dependants Grouped"].value_counts().sort_index(ascending=True)
customer_status = ["Existing Customer", "Attrited Customer"]

r = [0,1,2,3]

plt.bar(r, plot_exist, color='purple')
plt.bar(r, plot_att, color='yellow')

names = ["0-1", "2-3", "3-4", "5+"]
barwidth = 1

plt.xticks(r, names, fontweight='bold')
plt.xlabel('Number of dependents', fontsize=16)
plt.ylabel('Number of Customers', fontsize=16)
plt.legend(customer_status, loc=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-3062b471bb5b> in <module>
# ----> 1 dep_att_customer = merge_Q4_df.loc[Q4_df_drop["Attrition_Flag"]=="Attrited Customer"]
#       2 dep_exist_customer = merge_Q4_df.loc[Q4_df_drop["Attrition_Flag"]=="Existing Customer"]
#       3
#       4 plot_att = dep_att_customer["Dependants Grouped"].value_counts().sort_index(ascending=True)
#       5 plot_exist = dep_exist_customer["Dependants Grouped"].value_counts().sort_index(ascending=True)
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### 5. The relationship between card category and income? Are those with higher income on a better card? Are they more likely to stay or leave?

# %%
# columns needed for this are Card_Category, Income_Category, Attrition_Flag
Q5_columns = ["Gender", "Customer_Age", "Attrition_Flag"]
Q5_df = CCCP_data[Q5_columns]
Q5_df

# %% [markdown]
# ### 6. Do total transaction levels tie in with income levels? And is there any correlation between transaction amounts and how long customers have been inactive?

# %%
# columns needed for this are Total_Trans_Amt, Total_Trans_Ct, Months_Inactive_1_mon, Income_Category
Q6_columns = ["Gender", "Customer_Age", "Attrition_Flag"]
Q6_df = CCCP_data[Q6_columns]
Q6_df
